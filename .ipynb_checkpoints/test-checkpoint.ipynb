# %% [markdown]
# ## Animal Shelter
#
# I found some data, now I start to look into it
#
# Daten von "https://www.kaggle.com/datasets/thedevastator/austin-animal-center-data"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %% [markdown]
# I **restrict myself to dogs** and drop for this investigation all other animals from the dataset

# %% [markdown]
# **Intake:** each line of the dataset describes an animal, which has ben brought into the shelter.
#
# Number of column | Name of column | Datatype | Description
# :---|:---|:---|:----
# 1  |  `'Animal ID'` | categorical (nominal) | Unique indentification number of the animal
# 2  |  `'Name'` | categorical (`string`) | Name of the animal
# 3  |  `'DateTime'` | continuous (`Datetime`) | Date and time when the animal was brought to shelter
# 4  |  `'MonthYear'` | contiuous (`string` + `int`) |Month and Year of intake
# 5  |  `'Found Location'` | categorical (`string`) | Adress: found location or home adress
# 6  |  `'Intake Type'` | categorical (`string`) | How/why animal came to shelter
# 7  |  `'Intake Condition'` | categorical (`string`) | Health and body condition
# 8  |  `'Animal Type'` | categorical (`string`) | kind of animal
# 9  |  `'Sex upon intake'` | categorical (`string`) | gender and sex
# 10  |  `'Age upon intake'` | continous (`string`) | age X years/ Y month
# 11  |  `'Breed'` | categorical (`string`) | Breed of animal
# 12  |  `'Color'` | categorical (`string`) | Color of fur

# %% [markdown]
# **Outcome:** each line of the dataset describes an animal, which left the shelter.
#
# Number of column | Name of column | Datatype | Description
# :---|:---|:---|:----
# 1  |  `'Animal ID'` | categorical (nominal) | Unique indentification number of the animal
# 2  |  `'Name'` | categorical (`string`) | Name of the animal
# 3  |  `'DateTime'` | continuous (`Datetime`) | Date and time when the animal left the shelter
# 4  |  `'MonthYear'` | contiuous (`string` + `int`) |Month and Year of outcome
# 5  |  `'Outcome Type'` | categorical (`string`) | How it came out (Adoption...)
# 6  |  `'Outcome Subtype'` | categorical (`string`) | Further information of how it came out (Foster...)
# 7  |  `'Animal Type'` | categorical (`string`) | kind of animal
# 8  |  `'Sex upon Outcome'` | categorical (`string`) | gender and sex
# 10  |  `'Age upon Outcome'` | continous (`string`) | age X years/ Y month
# 11  |  `'Breed'` | categorical (`string`) | Breed of animal
# 12  |  `'Color'` | categorical (`string`) | Color of fur

# %%
#read data and select dogs + drop animal-Type
df_in = pd.read_csv("archive/AustinAnimalCenterIntakes.csv")
df_in = df_in[df_in["Animal Type"] == "Dog"]
df_in = df_in.drop("Animal Type", axis = 1)
#df_in = df_in[:1500]
df_in.head()
# Out:
#   Animal ID     Name                DateTime      MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM   January 2019
# 1   A706918    Belle  07/05/2015 12:59:00 PM      July 2015
# 2   A724273  Runster  04/14/2016 06:43:00 PM     April 2016
# 4   A682524      Rio  06/29/2014 10:38:00 AM      June 2014
# 5   A743852     Odin  02/18/2017 12:46:00 PM  February 2017
#
#                         Found Location      Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)            Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)            Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)            Stray           Normal
# 4        800 Grove Blvd in Austin (TX)            Stray           Normal
# 5                          Austin (TX)  Owner Surrender           Normal
#
#   Sex upon Intake Age upon Intake                                  Breed  \
# 0   Neutered Male         2 years                             Beagle Mix
# 1   Spayed Female         8 years               English Springer Spaniel
# 2     Intact Male       11 months                            Basenji Mix
# 4   Neutered Male         4 years  Doberman Pinsch/Australian Cattle Dog
# 5   Neutered Male         2 years                 Labrador Retriever Mix
#
#          Color
# 0     Tricolor
# 1  White/Liver
# 2  Sable/White
# 4     Tan/Gray
# 5    Chocolate

# %%
df_out = pd.read_csv("archive/AustinAnimalCenterOutcomes.csv")
df_out = df_out[df_out["Animal Type"] == "Dog"]
df_out = df_out.drop("Animal Type", axis = 1)
#df_out = df_out[:1500]
df_out.head(5)
# Out:
#    Animal ID      Name                DateTime MonthYear Date of Birth  \
# 1    A776359     Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 3    A720371     Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
# 5    A659412  Princess  10/05/2020 02:37:00 PM  Oct 2020    03/24/2013
# 6    A814515   Quentin  05/06/2020 07:59:00 AM  May 2020    03/01/2018
# 10   A840370     Tulip  08/19/2021 07:36:00 PM  Aug 2021    08/06/2019
#
#    Outcome Type Outcome Subtype Sex upon Outcome Age upon Outcome  \
# 1      Adoption             NaN    Neutered Male           1 year
# 3      Adoption             NaN    Neutered Male         4 months
# 5      Adoption             NaN    Spayed Female          7 years
# 6      Adoption          Foster    Neutered Male          2 years
# 10     Adoption             NaN    Spayed Female          2 years
#
#                                    Breed        Color
# 1                Chihuahua Shorthair Mix  White/Brown
# 3     Anatol Shepherd/Labrador Retriever         Buff
# 5                Chihuahua Shorthair Mix        Brown
# 6   American Foxhound/Labrador Retriever  White/Brown
# 10    Border Collie/Cardigan Welsh Corgi  Black/White

# %%
def getOverview(df):
    '''Returns summary about the data in the dataframe.

        Creates a dataFrame with datatypes, unique, nunique, number of missing values; 
               
        Args:
            df (pandas.dataFrame): a dataframe with rows and columns

        Returns:
            None
    '''
    df = df.copy()
    display(pd.DataFrame({'dtype': df.dtypes,                                   # Dtypes
                          'total': df.count(),                                  # number of valid entries
                          'missing_n': df.isna().sum(),                         # Number nan-entries
                          'missing_%': df.isna().mean()*100,                    # Ratio of missing values in %
                          'uniques_n': df.nunique(),                            # Caridinality (Number of unique values)
                          'uniques': [df[col].unique() for col in df.columns]   # List of unique values
                         }))
pd.set_option("display.float_format", "{:,.2f}".format)

# %%
getOverview(df_in)
getOverview(df_out)
# Out:
#                  dtype  total  missing_n  missing_%  uniques_n  \
# Animal ID          str  87192          0       0.00      73783
# Name               str  73426      13766      15.79      17980
# DateTime           str  87192          0       0.00      68727
# MonthYear          str  87192          0       0.00        123
# Found Location     str  87192          0       0.00      41624
# Intake Type        str  87192          0       0.00          6
# Intake Condition   str  87192          0       0.00         18
# Sex upon Intake    str  87190          2       0.00          5
# Age upon Intake    str  87191          1       0.00         49
# Breed              str  87192          0       0.00       2554
# Color              str  87192          0       0.00        392
#
#                                                             uniques
# Animal ID         [A786884, A706918, A724273, A682524, A743852, ...
# Name              [*Brock, Belle, Runster, Rio, Odin, Beowulf, M...
# DateTime          [01/03/2019 04:19:00 PM, 07/05/2015 12:59:00 P...
# MonthYear         [January 2019, July 2015, April 2016, June 201...
# Found Location    [2501 Magin Meadow Dr in Austin (TX), 9409 Blu...
# Intake Type       [Stray, Owner Surrender, Public Assist, Abando...
# Intake Condition  [Normal, Injured, Pregnant, Sick, Nursing, Age...
# Sex upon Intake   [Neutered Male, Spayed Female, Intact Male, In...
# Age upon Intake   [2 years, 8 years, 11 months, 4 years, 6 years...
# Breed             [Beagle Mix, English Springer Spaniel, Basenji...
# Color             [Tricolor, White/Liver, Sable/White, Tan/Gray,...
#                  dtype  total  missing_n  missing_%  uniques_n  \
# Animal ID          str  87091          0       0.00      73697
# Name               str  73355      13736      15.77      17899
# DateTime           str  87091          0       0.00      78096
# MonthYear          str  87091          0       0.00        123
# Date of Birth      str  87091          0       0.00       7717
# Outcome Type       str  87073         18       0.02          9
# Outcome Subtype    str  28804      58287      66.93         24
# Sex upon Outcome   str  87089          2       0.00          5
# Age upon Outcome   str  87089          2       0.00         49
# Breed              str  87091          0       0.00       2556
# Color              str  87091          0       0.00        393
#
#                                                             uniques
# Animal ID         [A776359, A720371, A659412, A814515, A840370, ...
# Name              [Gizmo, Moose, Princess, Quentin, Tulip, Fiona...
# DateTime          [07/18/2018 04:02:00 PM, 02/13/2016 05:59:00 P...
# MonthYear         [Jul 2018, Feb 2016, Oct 2020, May 2020, Aug 2...
# Date of Birth     [07/12/2017, 10/08/2015, 03/24/2013, 03/01/201...
# Outcome Type      [Adoption, Return to Owner, Transfer, Rto-Adop...
# Outcome Subtype   [nan, Foster, Out State, Partner, Aggressive, ...
# Sex upon Outcome  [Neutered Male, Spayed Female, Intact Female, ...
# Age upon Outcome  [1 year, 4 months, 7 years, 2 years, 9 years, ...
# Breed             [Chihuahua Shorthair Mix, Anatol Shepherd/Labr...
# Color             [White/Brown, Buff, Brown, Black/White, White/...

# %% [markdown]
# Despite the *Name* and the *Outcome Subtype*, we have very little missing data

# %% [markdown]
# Preparation of Data:
#
# - change types
# - separate MonthYear
# - Age upon Intake/Outcome: to int: in months
# - Separate Sex upon intake/outcome: gender and sex
# - oneHot: month, year, Intake Type, Intake Condition

# %%
def separateMonthYear(df):
    ''' manipulate DataFrame

        Column MonthYear is separated into Col Month and col Year, 
        string is converted to int
        col MonthYear is deleted
               
        ARGS:
            df: Dataframe 
        RETURN:
            manipulated DataFrame
    '''
    if "MonthYear" in df:
        df_clean = df.copy()
        #do not give format explicitely, since format_in = %B %Y and format_out = %b %Y pandas does it well
        df_clean["MonthYear"] = pd.to_datetime(df_clean["MonthYear"], 
                                                errors='coerce')
        df_clean["Month"] = df_clean["MonthYear"].dt.month
        df_clean["Year"] = df_clean["MonthYear"].dt.year
        df_clean.drop("MonthYear", inplace = True, axis = 1)
        
        return df_clean
        
    else:
        print("MonthYear is not in df.columns")
        return df

# %%
# we ignore the warning - it says that pandas uses a slower but more flexible parser for the datetime-conversion
# we ensured that no NaNs are in the new columns, hence the conversion worked fine
df_out = separateMonthYear(df_out)
df_in = separateMonthYear(df_in)
# Out:
# /tmp/ipykernel_356853/565976205.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean["MonthYear"] = pd.to_datetime(df_clean["MonthYear"],
# /tmp/ipykernel_356853/565976205.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean["MonthYear"] = pd.to_datetime(df_clean["MonthYear"],

# %%
def dateTime(df):
    '''Converts df["DateTime"] into datetime-object
    ARGS:
        df: Dataframe
    RETURN:
        None
    '''
    if "DateTime" in df:
        df_clean = df.copy()
        df_clean["DateTime"] = pd.to_datetime(df_clean["DateTime"], format='%m/%d/%Y %I:%M:%S %p')
        return df_clean
    else:
        print("DateTime is not in df.columns")
        return df

# %%
df_out = dateTime(df_out)
df_in = dateTime(df_in)

# %%
import string
import numpy as np
def convertAgeToMonth(df):
    '''Converts Age upon intake/outcome from string to month(int)
    ARGS:
        df: dataframe
    RETURNS:
        df: dataframe with age upon intake/outcome (months)
    '''
   
    df_month = df.copy()
   
    if "Age upon Intake" in df_month:
        temp_series = df_month["Age upon Intake"].fillna("")
        numbers = temp_series.str.extract(r'(\d+)', expand = False).astype(float)
        ismonth = temp_series.str.contains('month', case=False, na=False)
        df_month['Age upon Intake (months)'] = np.where(
            ismonth,
            numbers,                # Wenn Monat: Behalte die Zahl
            numbers * 12            # Wenn Jahr: Multipliziere mit 12
            )
        df_month = df_month.drop('Age upon Intake', axis = 1)
        return df_month
    elif "Age upon Outcome" in df_month:
        temp_series = df_month["Age upon Outcome"].fillna("")
        numbers = temp_series.str.extract(r'(\d+)', expand = False).astype(float)
        ismonth = temp_series.str.contains('month', case=False, na=False)
        df_month['Age upon Outcome (months)'] = np.where(
            ismonth,
            numbers,                # Wenn Monat: Behalte die Zahl
            numbers * 12            # Wenn Jahr: Multipliziere mit 12
            )
        df_month = df_month.drop('Age upon Outcome', axis = 1)
        return df_month
    else:
        print("Neither Age upon Intake, nor Age upon Outcome are column of df")
        return df

# %%
df_in = convertAgeToMonth(df_in)
df_out = convertAgeToMonth(df_out)

# %%
df_in["Age upon Intake (months)"] = df_in["Age upon Intake (months)"].astype("Int64")
df_out["Age upon Outcome (months)"] = df_out["Age upon Outcome (months)"].astype("Int64")

# %%
getOverview(df_in)
getOverview(df_out)
# Out:
#                                    dtype  total  missing_n  missing_%  \
# Animal ID                            str  87192          0       0.00
# Name                                 str  73426      13766      15.79
# DateTime                  datetime64[us]  87192          0       0.00
# Found Location                       str  87192          0       0.00
# Intake Type                          str  87192          0       0.00
# Intake Condition                     str  87192          0       0.00
# Sex upon Intake                      str  87190          2       0.00
# Breed                                str  87192          0       0.00
# Color                                str  87192          0       0.00
# Month                              int32  87192          0       0.00
# Year                               int32  87192          0       0.00
# Age upon Intake (months)           Int64  87191          1       0.00
#
#                           uniques_n  \
# Animal ID                     73783
# Name                          17980
# DateTime                      68727
# Found Location                41624
# Intake Type                       6
# Intake Condition                 18
# Sex upon Intake                   5
# Breed                          2554
# Color                           392
# Month                            12
# Year                             11
# Age upon Intake (months)         34
#
#                                                                     uniques
# Animal ID                 [A786884, A706918, A724273, A682524, A743852, ...
# Name                      [*Brock, Belle, Runster, Rio, Odin, Beowulf, M...
# DateTime                  [2019-01-03 16:19:00, 2015-07-05 12:59:00, 201...
# Found Location            [2501 Magin Meadow Dr in Austin (TX), 9409 Blu...
# Intake Type               [Stray, Owner Surrender, Public Assist, Abando...
# Intake Condition          [Normal, Injured, Pregnant, Sick, Nursing, Age...
# Sex upon Intake           [Neutered Male, Spayed Female, Intact Male, In...
# Breed                     [Beagle Mix, English Springer Spaniel, Basenji...
# Color                     [Tricolor, White/Liver, Sable/White, Tan/Gray,...
# Month                               [1, 7, 4, 6, 2, 3, 10, 9, 11, 8, 5, 12]
# Year                      [2019, 2015, 2016, 2014, 2017, 2023, 2022, 202...
# Age upon Intake (months)  [24, 96, 11, 48, 72, 5, 2, 216, 12, 1, 108, 4,...
#                                     dtype  total  missing_n  missing_%  \
# Animal ID                             str  87091          0       0.00
# Name                                  str  73355      13736      15.77
# DateTime                   datetime64[us]  87091          0       0.00
# Date of Birth                         str  87091          0       0.00
# Outcome Type                          str  87073         18       0.02
# Outcome Subtype                       str  28804      58287      66.93
# Sex upon Outcome                      str  87089          2       0.00
# Breed                                 str  87091          0       0.00
# Color                                 str  87091          0       0.00
# Month                               int32  87091          0       0.00
# Year                                int32  87091          0       0.00
# Age upon Outcome (months)           Int64  87089          2       0.00
#
#                            uniques_n  \
# Animal ID                      73697
# Name                           17899
# DateTime                       78096
# Date of Birth                   7717
# Outcome Type                       9
# Outcome Subtype                   24
# Sex upon Outcome                   5
# Breed                           2556
# Color                            393
# Month                             12
# Year                              11
# Age upon Outcome (months)         34
#
#                                                                      uniques
# Animal ID                  [A776359, A720371, A659412, A814515, A840370, ...
# Name                       [Gizmo, Moose, Princess, Quentin, Tulip, Fiona...
# DateTime                   [2018-07-18 16:02:00, 2016-02-13 17:59:00, 202...
# Date of Birth              [07/12/2017, 10/08/2015, 03/24/2013, 03/01/201...
# Outcome Type               [Adoption, Return to Owner, Transfer, Rto-Adop...
# Outcome Subtype            [nan, Foster, Out State, Partner, Aggressive, ...
# Sex upon Outcome           [Neutered Male, Spayed Female, Intact Female, ...
# Breed                      [Chihuahua Shorthair Mix, Anatol Shepherd/Labr...
# Color                      [White/Brown, Buff, Brown, Black/White, White/...
# Month                                [7, 2, 10, 5, 8, 6, 3, 12, 4, 11, 1, 9]
# Year                       [2018, 2016, 2020, 2021, 2017, 2019, 2023, 201...
# Age upon Outcome (months)  [12, 4, 84, 24, 108, 120, 96, 36, 2, 7, 72, 48...

# %%
#find and drop duplicates
duplicates_mask = df_out.duplicated()
print(f"Number of duplicated rows in df_out: {duplicates_mask.sum()}")
print(f"Number of duplicated rows in df_in: {df_in.duplicated().sum()}")
df_out = df_out.drop_duplicates()
df_in = df_in.drop_duplicates()
# Out:
# Number of duplicated rows in df_out: 10
# Number of duplicated rows in df_in: 16

# %%
# 1. Find all IDs, which occur mor than once
# group by 'Animal ID' and count occurances
id_counts = df_in['Animal ID'].value_counts()

# filter only IDs which occur more than 1
duplicate_ids = id_counts[id_counts > 1].index

print(f"Number of at least doubled IDs in df_in: {len(duplicate_ids)}")

# 2. create new dataframe with all rows having these doubled IDs (original and copy) 
df_duplicates = df_in[df_in['Animal ID'].isin(duplicate_ids)].copy()

# 3. Sort
df_duplicates = df_duplicates.sort_values('Animal ID')

# 4. show result
print(f"\nNumber of rows in new df: {len(df_duplicates)}")
display(df_duplicates.head(10))
# Out:
# Number of at least doubled IDs in df_in: 9885
#
# Number of rows in new df: 23278
#        Animal ID    Name            DateTime  \
# 4368     A006100   Scamp 2014-12-19 10:21:00
# 97793    A006100   Scamp 2014-03-07 14:26:00
# 24086    A006100   Scamp 2017-12-07 14:07:00
# 131442   A245945  Boomer 2015-05-20 22:34:00
# 106423   A245945  Boomer 2014-07-03 17:55:00
# 866      A287017  Stitch 2015-08-16 12:19:00
# 127907   A287017  Stitch 2014-12-12 07:04:00
# 34608    A307010  Cooper 2016-09-25 12:51:00
# 42612    A307010  Cooper 2017-06-01 11:47:00
# 61795    A322813   Tyson 2015-03-05 14:49:00
#
#                                            Found Location      Intake Type  \
# 4368                    8700 Research Blvd in Austin (TX)    Public Assist
# 97793                        8700 Research in Austin (TX)    Public Assist
# 24086       Colony Creek And Hunters Trace in Austin (TX)            Stray
# 131442                   7403 Blessing Ave in Austin (TX)            Stray
# 106423                  Garden And Mildred in Austin (TX)            Stray
# 866                     6620 Deatonhill Dr in Austin (TX)            Stray
# 127907  Lazy Oaks /Westgate William Cannon in Austin (TX)            Stray
# 34608        Freidrich Lane And St Elmo Rd in Austin (TX)            Stray
# 42612                     806 Castle Ridge in Austin (TX)  Owner Surrender
# 61795                                         Austin (TX)    Public Assist
#
#        Intake Condition Sex upon Intake                    Breed  \
# 4368             Normal   Neutered Male     Spinone Italiano Mix
# 97793            Normal   Neutered Male     Spinone Italiano Mix
# 24086            Normal   Neutered Male     Spinone Italiano Mix
# 131442           Normal   Neutered Male   Labrador Retriever Mix
# 106423           Normal   Neutered Male   Labrador Retriever Mix
# 866              Normal   Spayed Female  Chihuahua Shorthair Mix
# 127907             Aged   Spayed Female  Chihuahua Shorthair Mix
# 34608            Normal   Neutered Male               Beagle Mix
# 42612            Normal   Neutered Male               Beagle Mix
# 61795            Normal   Neutered Male           Rottweiler Mix
#
#                Color  Month  Year  Age upon Intake (months)
# 4368    Yellow/White     12  2014                        84
# 97793   Yellow/White      3  2014                        72
# 24086   Yellow/White     12  2017                       120
# 131442           Tan      5  2015                       180
# 106423           Tan      7  2014                       168
# 866      Black/White      8  2015                       168
# 127907   Black/White     12  2014                       156
# 34608       Tricolor      9  2016                       156
# 42612       Tricolor      6  2017                       168
# 61795    Black/Brown      3  2015                       132

# %%
# 1. Find all IDs, which occur mor than once
# group by 'Animal ID' and count occurances
id_counts_out = df_out['Animal ID'].value_counts()

# filter only IDs which occur more than 1
duplicate_ids_out = id_counts_out[id_counts_out > 1].index

print(f"Number of at least doubled IDs in df_out: {len(duplicate_ids_out)}")

# 2. create new dataframe with all rows having these doubled IDs (original and copy) 
df_duplicates_out = df_out[df_out['Animal ID'].isin(duplicate_ids_out)].copy()

# 3. Sort
df_duplicates_out = df_duplicates_out.sort_values('Animal ID')

# 4. show result
print(f"\nNumber of rows in new df_out: {len(df_duplicates_out)}")
display(df_duplicates_out.head(10))
# Out:
# Number of at least doubled IDs in df_out: 9881
#
# Number of rows in new df_out: 23265
#        Animal ID    Name            DateTime Date of Birth     Outcome Type  \
# 125158   A006100   Scamp 2014-03-08 17:10:00    07/09/2007  Return to Owner
# 61555    A006100   Scamp 2014-12-20 16:35:00    07/09/2007  Return to Owner
# 110187   A006100   Scamp 2017-12-07 00:00:00    07/09/2007  Return to Owner
# 98468    A245945  Boomer 2014-07-04 15:26:00    05/23/2000  Return to Owner
# 75479    A245945  Boomer 2015-05-25 11:49:00    05/23/2000         Transfer
# 26463    A287017  Stitch 2014-12-12 16:49:00    05/13/2001  Return to Owner
# 77255    A287017  Stitch 2015-08-16 13:31:00    05/13/2001  Return to Owner
# 41456    A307010  Cooper 2016-09-28 09:36:00    03/04/2003  Return to Owner
# 102980   A307010  Cooper 2017-06-05 15:11:00    03/04/2003  Return to Owner
# 58129    A322813   Tyson 2015-12-24 14:31:00    03/26/2003  Return to Owner
#
#        Outcome Subtype Sex upon Outcome                    Breed  \
# 125158             NaN    Neutered Male     Spinone Italiano Mix
# 61555              NaN    Neutered Male     Spinone Italiano Mix
# 110187             NaN    Neutered Male     Spinone Italiano Mix
# 98468              NaN    Neutered Male   Labrador Retriever Mix
# 75479          Partner    Neutered Male   Labrador Retriever Mix
# 26463              NaN    Spayed Female  Chihuahua Shorthair Mix
# 77255              NaN    Spayed Female  Chihuahua Shorthair Mix
# 41456              NaN    Neutered Male               Beagle Mix
# 102980             NaN    Neutered Male               Beagle Mix
# 58129              NaN    Neutered Male           Rottweiler Mix
#
#                Color  Month  Year  Age upon Outcome (months)
# 125158  Yellow/White      3  2014                         72
# 61555   Yellow/White     12  2014                         84
# 110187  Yellow/White     12  2017                        120
# 98468            Tan      7  2014                        168
# 75479            Tan      5  2015                        180
# 26463    Black/White     12  2014                        156
# 77255    Black/White      8  2015                        168
# 41456       Tricolor      9  2016                        156
# 102980      Tricolor      6  2017                        168
# 58129    Black/Brown     12  2015                        144

# %%
df_in['DateTime'] = pd.to_datetime(df_in['DateTime'])
df_out['DateTime'] = pd.to_datetime(df_out['DateTime'])
df_in['Number of Intake'] = df_in.groupby('Animal ID')['DateTime'].rank(method='min').astype('Int64')
df_out['Number of Outcome'] = df_out.groupby('Animal ID')['DateTime'].rank(method='min').astype('Int64')

# %%
#Create target-column: "left shelter" using df_out["Animal ID"]

ids_left = df_out['Animal ID'].unique()

# 2.  True/False zu
# Wenn die ID in der Liste der eindeutigen IDs ist -> True
df_in['Left'] = df_in['Animal ID'].isin(ids_left)
print(f"Einzigartige IDs in df_out: {len(ids_left)}")
print(f"Tiere in df_dogs, die 'Left' = True haben: {df_in['Left'].sum()}")
# Out:
# Einzigartige IDs in df_out: 73697
# Tiere in df_dogs, die 'Left' = True haben: 86709

# %% [markdown]
# **Bisher** habe ich die Daten gesichtet und eine Fragestellung entworfen.
#
# Damit es in der ersten Runde nicht zu schwer wird, werde ich doppelte Adoptionen nicht gesondert betrachten.
#
# Ziel ist zunächst ein Model zu entwickeln, dass vorhersagen kann, ob das Tier das Tierheim verlassen wird,
# Dazu muss **Intake Condition**, **Intake Type**, **Sex upon Intake** noch encoded werden.

# %%
df_out["Sex upon Outcome"].unique()
# Out:
# <StringArray>
# ['Neutered Male', 'Spayed Female', 'Intact Female',   'Intact Male',
#        'Unknown',             nan]
# Length: 6, dtype: str

# %%
df_in["Sex upon Intake"] = df_in["Sex upon Intake"].fillna("Missing")
df_out["Sex upon Outcome"] = df_out["Sex upon Outcome"].fillna("Missing")

# %%
def separateSex(df, col):
    '''
    Separates column col in Sex and Status
    ARGS:
        df: DataFrame
        col: Column Name
    Return:
        DataFrame, with Columns Sex and Status instead of col
    '''
    df_clean = df.copy()
    split_cols = df_clean[col].str.split(" ", n=1, expand = True)
    
    df_clean["Status"] = split_cols[0]    
    df_clean["Sex"] = split_cols[1]

    return df_clean

# %%
df_in = separateSex(df_in, "Sex upon Intake")
df_out = separateSex(df_out, "Sex upon Outcome")

# %%
df_in["Sex"]=df_in["Sex"].fillna("Missing")
df_out["Sex"]=df_out["Sex"].fillna("Missing")

# %%
#Prepare for merging: rename columns

df_in = df_in.rename(columns={
    'Month': 'Month_in',
    'Year': 'Year_in',
    "Sex" : "Sex_in",
    "Status" : "Status_in",
    "DateTime" : "DateTime_in"
})


df_out = df_out.rename(columns={
    'Month': 'Month_out',
    'Year': 'Year_out',
    "Sex" : "Sex_out",
    "Status" : "Status_out",
    "DateTime" : "DateTime_out"
})
# 3. Hilfs-Spalte für die Reihenfolge erstellen (Cumulative Count pro Tier)
# Dies stellt sicher, dass der 1. Eintrag mit dem 1. Austritt, der 2. mit dem 2. usw. verknüpft wird.
df_in['event_id'] = df_in.groupby('Animal ID').cumcount() + 1
df_out['event_id'] = df_out.groupby('Animal ID').cumcount() + 1

# 4. Merge durchführen (Left Join: Alle Intakes behalten, auch wenn kein Outcome existiert)
# Wir joinen auf 'Animal ID' und 'event_id'
merged_df = pd.merge(
    df_in,
    df_out[['Animal ID', 'event_id', 'Month_out', 'Year_out', 'Age upon Outcome (months)', "DateTime_out",'Number of Outcome', "Outcome Type" ,	"Outcome Subtype", "Status_out","Sex_out"]],
    on=['Animal ID', 'event_id'],
    how='left'
)

# 5. Fehlende Outcome-Werte füllen
# Wenn ein Tier nicht im Outcome-DataFrame war, sind die Spalten NaN.
# Wir setzen Number_out auf 0 und die anderen Outcome-Spalten auf 0 oder NaN (je nach Bedarf).
# Hier setzen wir Number_out auf 0, wie gewünscht.
merged_df['Number of Outcome'] = merged_df['Number of Outcome'].fillna(0).astype(int)

# Optional: Auch Age_out_months und andere auf 0 setzen, wenn sie NaN sind, 
# oder sie als NaN lassen, um zu zeigen, dass kein Outcome stattfand.
# Ich lasse sie hier als NaN, außer Number_out, da 0 Monate biologisch falsch sein könnte.
# Wenn du explizit 0 für alles willst:
# merged_df[['Month_out', 'Year_out', 'Age_out_months']] = merged_df[['Month_out', 'Year_out', 'Age_out_months']].fillna(0)

# 6. Event_id entfernen (war nur für den Merge nötig)
merged_df = merged_df.drop(columns=['event_id'])

# Sortieren (optional, aber übersichtlich)
merged_df = merged_df.sort_values(by=['Animal ID', 'Month_in', 'Year_in']).reset_index(drop=True)

# Ergebnis anzeigen
display(merged_df.head())
# Out:
#   Animal ID    Name         DateTime_in  \
# 0   A006100   Scamp 2014-03-07 14:26:00
# 1   A006100   Scamp 2014-12-19 10:21:00
# 2   A006100   Scamp 2017-12-07 14:07:00
# 3   A047759    Oreo 2014-04-02 15:55:00
# 4   A134067  Bandit 2013-11-16 09:02:00
#
#                                   Found Location      Intake Type  \
# 0                   8700 Research in Austin (TX)    Public Assist
# 1              8700 Research Blvd in Austin (TX)    Public Assist
# 2  Colony Creek And Hunters Trace in Austin (TX)            Stray
# 3                                    Austin (TX)  Owner Surrender
# 4             12034 Research Blvd in Austin (TX)    Public Assist
#
#   Intake Condition Sex upon Intake                 Breed         Color  \
# 0           Normal   Neutered Male  Spinone Italiano Mix  Yellow/White
# 1           Normal   Neutered Male  Spinone Italiano Mix  Yellow/White
# 2           Normal   Neutered Male  Spinone Italiano Mix  Yellow/White
# 3           Normal   Neutered Male             Dachshund      Tricolor
# 4          Injured   Neutered Male     Shetland Sheepdog   Brown/White
#
#    Month_in  ...  Sex_in  Month_out  Year_out  Age upon Outcome (months)  \
# 0         3  ...    Male       3.00  2,014.00                         72
# 1        12  ...    Male      12.00  2,014.00                         84
# 2        12  ...    Male      12.00  2,017.00                        120
# 3         4  ...    Male       4.00  2,014.00                        120
# 4        11  ...    Male      11.00  2,013.00                        192
#
#          DateTime_out Number of Outcome     Outcome Type  Outcome Subtype  \
# 0 2014-03-08 17:10:00                 1  Return to Owner              NaN
# 1 2014-12-20 16:35:00                 2  Return to Owner              NaN
# 2 2017-12-07 00:00:00                 3  Return to Owner              NaN
# 3 2014-04-07 15:12:00                 1         Transfer          Partner
# 4 2013-11-16 11:54:00                 1  Return to Owner              NaN
#
#    Status_out Sex_out
# 0    Neutered    Male
# 1    Neutered    Male
# 2    Neutered    Male
# 3    Neutered    Male
# 4    Neutered    Male
#
# [5 rows x 25 columns]

# %%
getOverview(merged_df)
# Out:
#                                     dtype  total  missing_n  missing_%  \
# Animal ID                             str  87176          0       0.00
# Name                                  str  73411      13765      15.79
# DateTime_in                datetime64[us]  87176          0       0.00
# Found Location                        str  87176          0       0.00
# Intake Type                           str  87176          0       0.00
# Intake Condition                      str  87176          0       0.00
# Sex upon Intake                       str  87176          0       0.00
# Breed                                 str  87176          0       0.00
# Color                                 str  87176          0       0.00
# Month_in                            int32  87176          0       0.00
# Year_in                             int32  87176          0       0.00
# Age upon Intake (months)            Int64  87175          1       0.00
# Number of Intake                    Int64  87176          0       0.00
# Left                                 bool  87176          0       0.00
# Status_in                             str  87176          0       0.00
# Sex_in                                str  87176          0       0.00
# Month_out                         float64  86623        553       0.63
# Year_out                          float64  86623        553       0.63
# Age upon Outcome (months)           Int64  86621        555       0.64
# DateTime_out               datetime64[us]  86623        553       0.63
# Number of Outcome                   int64  87176          0       0.00
# Outcome Type                          str  86606        570       0.65
# Outcome Subtype                       str  28588      58588      67.21
# Status_out                            str  86623        553       0.63
# Sex_out                               str  86623        553       0.63
#
#                            uniques_n  \
# Animal ID                      73783
# Name                           17980
# DateTime_in                    68727
# Found Location                 41624
# Intake Type                        6
# Intake Condition                  18
# Sex upon Intake                    6
# Breed                           2554
# Color                            392
# Month_in                          12
# Year_in                           11
# Age upon Intake (months)          34
# Number of Intake                  33
# Left                               2
# Status_in                          5
# Sex_in                             3
# Month_out                         12
# Year_out                          11
# Age upon Outcome (months)         34
# DateTime_out                   77668
# Number of Outcome                 34
# Outcome Type                       9
# Outcome Subtype                   24
# Status_out                         5
# Sex_out                            3
#
#                                                                      uniques
# Animal ID                  [A006100, A047759, A134067, A141142, A163459, ...
# Name                       [Scamp, Oreo, Bandit, Bettie, Sasha, Pep, Boti...
# DateTime_in                [2014-03-07 14:26:00, 2014-12-19 10:21:00, 201...
# Found Location             [8700 Research in Austin (TX), 8700 Research B...
# Intake Type                [Public Assist, Stray, Owner Surrender, Euthan...
# Intake Condition           [Normal, Injured, Aged, Sick, Medical, Other, ...
# Sex upon Intake            [Neutered Male, Spayed Female, Intact Female, ...
# Breed                      [Spinone Italiano Mix, Dachshund, Shetland She...
# Color                      [Yellow/White, Tricolor, Brown/White, Black/Wh...
# Month_in                             [3, 12, 4, 11, 9, 10, 2, 8, 7, 6, 5, 1]
# Year_in                    [2014, 2017, 2013, 2015, 2016, 2018, 2019, 202...
# Age upon Intake (months)   [72, 84, 120, 192, 180, 216, 168, 204, 156, 14...
# Number of Intake           [1, 2, 3, 5, 4, 6, 7, 8, 9, 10, 11, 13, 12, 14...
# Left                                                           [True, False]
# Status_in                       [Neutered, Spayed, Intact, Unknown, Missing]
# Sex_in                                               [Male, Female, Missing]
# Month_out                  [3.0, 12.0, 4.0, 11.0, 9.0, 2.0, 10.0, 8.0, 7....
# Year_out                   [2014.0, 2017.0, 2013.0, 2015.0, 2016.0, 2018....
# Age upon Outcome (months)  [72, 84, 120, 192, 180, 216, 168, 204, 156, 14...
# DateTime_out               [2014-03-08 17:10:00, 2014-12-20 16:35:00, 201...
# Number of Outcome          [1, 2, 3, 4, 5, 6, 0, 7, 8, 9, 10, 11, 14, 12,...
# Outcome Type               [Return to Owner, Transfer, Adoption, Euthanas...
# Outcome Subtype            [nan, Partner, Foster, Suffering, Medical, Beh...
# Status_out                 [Neutered, Spayed, Intact, nan, Unknown, Missing]
# Sex_out                                         [Male, Female, nan, Missing]

# %%
time_in = merged_df.loc[1,"DateTime_out"] - merged_df.loc[1,"DateTime_in"]
print(time_in)
# Out:
# 1 days 06:14:00

# %%
import datetime

# %%
def makeColumnStayedInShelter(df):
    '''
    Creates new Column in which the time in shelter is written

    ARGS:
        df (dataframe)
    RETURNS:
        df_new (dataframe) with pd.Timedelta Column 
    '''
    df_new = df.copy()
    #if no outcome data is given, the dog is still in shelter (might lead to very old dogs)
    df_new["Temp"] = df_new["DateTime_out"].fillna(pd.to_datetime(datetime.datetime.now()))
    df_new["Time in shelter"] = df_new["Temp"] - df_new["DateTime_in"]
    #check whether left on same day, but hour of left = 0:00 (i suggest just not written down)
    #this is the special case. If a time is given, this suggestion is less valid 
    same_day = df_new["DateTime_in"].dt.date == df_new["Temp"].dt.date
    is_midnight = df_new["Temp"].dt.time == datetime.time(0, 0)
    mask_special_case = same_day & is_midnight
    
    # We set in this case the Time in shelter to 6 hours (w.l.o.g.) (pd.Timedelta(hours=5))
    df_new.loc[mask_special_case, "Time in shelter"] = pd.Timedelta(hours=5)
    
    # --- treat negative values ---
    # negative values occur, if DateTime_out is before DateTime_in
    # in this case, we suggest wrong data and set it to NaT
    
    mask_negative = df_new["Time in shelter"] < pd.Timedelta(0)
    df_new.loc[mask_negative, "Time in shelter"] = pd.NaT
    
    # drop temporary column
    df_new = df_new.drop("Temp", axis = 1)
    return df_new

# %%
merged_df = merged_df.drop("Sex upon Intake", axis = 1)

# %%
merged_df = makeColumnStayedInShelter(merged_df)

# %%
merged_df.head()
# Out:
#   Animal ID    Name         DateTime_in  \
# 0   A006100   Scamp 2014-03-07 14:26:00
# 1   A006100   Scamp 2014-12-19 10:21:00
# 2   A006100   Scamp 2017-12-07 14:07:00
# 3   A047759    Oreo 2014-04-02 15:55:00
# 4   A134067  Bandit 2013-11-16 09:02:00
#
#                                   Found Location      Intake Type  \
# 0                   8700 Research in Austin (TX)    Public Assist
# 1              8700 Research Blvd in Austin (TX)    Public Assist
# 2  Colony Creek And Hunters Trace in Austin (TX)            Stray
# 3                                    Austin (TX)  Owner Surrender
# 4             12034 Research Blvd in Austin (TX)    Public Assist
#
#   Intake Condition                 Breed         Color  Month_in  Year_in  \
# 0           Normal  Spinone Italiano Mix  Yellow/White         3     2014
# 1           Normal  Spinone Italiano Mix  Yellow/White        12     2014
# 2           Normal  Spinone Italiano Mix  Yellow/White        12     2017
# 3           Normal             Dachshund      Tricolor         4     2014
# 4          Injured     Shetland Sheepdog   Brown/White        11     2013
#
#    ...  Month_out  Year_out  Age upon Outcome (months)        DateTime_out  \
# 0  ...       3.00  2,014.00                         72 2014-03-08 17:10:00
# 1  ...      12.00  2,014.00                         84 2014-12-20 16:35:00
# 2  ...      12.00  2,017.00                        120 2017-12-07 00:00:00
# 3  ...       4.00  2,014.00                        120 2014-04-07 15:12:00
# 4  ...      11.00  2,013.00                        192 2013-11-16 11:54:00
#
#   Number of Outcome     Outcome Type  Outcome Subtype  Status_out Sex_out  \
# 0                 1  Return to Owner              NaN    Neutered    Male
# 1                 2  Return to Owner              NaN    Neutered    Male
# 2                 3  Return to Owner              NaN    Neutered    Male
# 3                 1         Transfer          Partner    Neutered    Male
# 4                 1  Return to Owner              NaN    Neutered    Male
#
#    Time in shelter
# 0  1 days 02:44:00
# 1  1 days 06:14:00
# 2  0 days 05:00:00
# 3  4 days 23:17:00
# 4  0 days 02:52:00
#
# [5 rows x 25 columns]

# %%
merged_df[merged_df["Time in shelter"] < pd.Timedelta(0)]
# Out:
# Empty DataFrame
# Columns: [Animal ID, Name, DateTime_in, Found Location, Intake Type, Intake Condition, Breed, Color, Month_in, Year_in, Age upon Intake (months), Number of Intake, Left, Status_in, Sex_in, Month_out, Year_out, Age upon Outcome (months), DateTime_out, Number of Outcome, Outcome Type, Outcome Subtype, Status_out, Sex_out, Time in shelter]
# Index: []
#
# [0 rows x 25 columns]

# %%
df_in[df_in["Name"] == "Lil Baby"]
# Out:
#        Animal ID      Name         DateTime_in  \
# 20175    A876313  Lil Baby 2023-03-13 11:10:00
# 145289   A889898  Lil Baby 2023-10-19 18:47:00
# 153958   A889898  Lil Baby 2023-09-29 11:28:00
#
#                                 Found Location      Intake Type  \
# 20175   Community First Village in Austin (TX)            Stray
# 145289                             Austin (TX)  Owner Surrender
# 153958          5105 Acorn Cove in Austin (TX)    Public Assist
#
#        Intake Condition Sex upon Intake  \
# 20175            Normal   Intact Female
# 145289           Normal   Spayed Female
# 153958           Normal   Spayed Female
#
#                                         Breed        Color  Month_in  Year_in  \
# 20175      Black Mouth Cur/Labrador Retriever   Fawn/White         3     2023
# 145289  Yorkshire Terrier/Chihuahua Shorthair  Black/White        10     2023
# 153958  Yorkshire Terrier/Chihuahua Shorthair  Black/White         9     2023
#
#         Age upon Intake (months)  Number of Intake  Left Status_in  Sex_in  \
# 20175                          8                 1  True    Intact  Female
# 145289                       120                 2  True    Spayed  Female
# 153958                       120                 1  True    Spayed  Female
#
#         event_id
# 20175          1
# 145289         1
# 153958         2

# %%
df_out[df_out["Name"] == "Lil Baby"]
# Out:
#        Animal ID      Name        DateTime_out Date of Birth     Outcome Type  \
# 60029    A889898  Lil Baby 2023-10-03 18:08:00    09/29/2013  Return to Owner
# 108458   A876313  Lil Baby 2023-03-14 14:21:00    06/13/2022  Return to Owner
# 154142   A889898  Lil Baby 2023-10-21 13:12:00    09/29/2013         Adoption
#
#        Outcome Subtype Sex upon Outcome  \
# 60029              NaN    Spayed Female
# 108458             NaN    Intact Female
# 154142             NaN    Spayed Female
#
#                                         Breed        Color  Month_out  \
# 60029   Yorkshire Terrier/Chihuahua Shorthair  Black/White         10
# 108458     Black Mouth Cur/Labrador Retriever   Fawn/White          3
# 154142  Yorkshire Terrier/Chihuahua Shorthair  Black/White         10
#
#         Year_out  Age upon Outcome (months)  Number of Outcome Status_out  \
# 60029       2023                        120                  1     Spayed
# 108458      2023                          9                  1     Intact
# 154142      2023                        120                  2     Spayed
#
#        Sex_out  event_id
# 60029   Female         1
# 108458  Female         1
# 154142  Female         2

# %%
merged_df[merged_df["Name"]=="Lil Baby"]
# Out:
#       Animal ID      Name         DateTime_in  \
# 83980   A876313  Lil Baby 2023-03-13 11:10:00
# 86467   A889898  Lil Baby 2023-09-29 11:28:00
# 86468   A889898  Lil Baby 2023-10-19 18:47:00
#
#                                Found Location      Intake Type  \
# 83980  Community First Village in Austin (TX)            Stray
# 86467          5105 Acorn Cove in Austin (TX)    Public Assist
# 86468                             Austin (TX)  Owner Surrender
#
#       Intake Condition                                  Breed        Color  \
# 83980           Normal     Black Mouth Cur/Labrador Retriever   Fawn/White
# 86467           Normal  Yorkshire Terrier/Chihuahua Shorthair  Black/White
# 86468           Normal  Yorkshire Terrier/Chihuahua Shorthair  Black/White
#
#        Month_in  Year_in  ...  Month_out  Year_out  Age upon Outcome (months)  \
# 83980         3     2023  ...       3.00  2,023.00                          9
# 86467         9     2023  ...      10.00  2,023.00                        120
# 86468        10     2023  ...      10.00  2,023.00                        120
#
#              DateTime_out Number of Outcome     Outcome Type  Outcome Subtype  \
# 83980 2023-03-14 14:21:00                 1  Return to Owner              NaN
# 86467 2023-10-21 13:12:00                 2         Adoption              NaN
# 86468 2023-10-03 18:08:00                 1  Return to Owner              NaN
#
#        Status_out Sex_out  Time in shelter
# 83980      Intact  Female  1 days 03:11:00
# 86467      Spayed  Female 22 days 01:44:00
# 86468      Spayed  Female              NaT
#
# [3 rows x 25 columns]

# %% [markdown]
# **Some** figures

# %%
#target
crosstab = pd.crosstab(index = merged_df["Number of Outcome"], columns = "ratio", normalize = True)
#display(crosstab)
crosstab.plot(kind = "pie", y = "ratio")
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns
num_df = merged_df.select_dtypes(include=['number'])

plt.figure(figsize = (10,8))
sns.heatmap(num_df.corr().abs(), annot = True )
# Out:
# <Axes: >

# %%
def numplot(col, data = num_df, save_plot = False):
    """
        Plot histogram, Boxplot and densityplot
        ARGS
            col: column to plot
            data: dataframe (default: df)
            key: Target column (default: IsBadBuy)
            save_plot (bool): save plot as png-file (default: False)
        RETURN:
            None
    """
    fig, ax = plt.subplots(ncols = 3, figsize = (16,3))
    sns.boxplot(data = data,y = col, ax = ax[0])
    data[col].plot(kind = "hist", bins = 20, ax = ax[1], alpha = 0.3, density = True)
    data[col].plot(kind = "kde", ax = ax[2])
    if save_plot:
        fig.savefig(f'numplot_{col}.png')
numcol = ['Month_in', 'Year_in', 'Age upon Intake (months)', 'Number of Intake',
       'Month_out', 'Year_out', 'Age upon Outcome (months)',
       'Number of Outcome']

for num in numcol:
    numplot(num)

# %%
num_df.columns
# Out:
# Index(['Month_in', 'Year_in', 'Age upon Intake (months)', 'Number of Intake',
#        'Month_out', 'Year_out', 'Age upon Outcome (months)',
#        'Number of Outcome', 'Time in shelter'],
#       dtype='str')

# %%
hours = merged_df["Time in shelter"].dt.total_seconds() / 3600/24
fig, ax = plt.subplots(ncols = 2, figsize=(10, 6))
#sns.boxplot(data = data,y = col, ax = ax[0])
hours.plot(kind = "hist", bins = 20, ax = ax[0], alpha = 0.3, density = True)
hours.plot(kind = "kde", ax = ax[1])
plt.title("Verteilung der Zeit im Shelter (in Tagen)")
plt.xlabel("Zeit im Shelter (Tage)")
plt.ylabel("Dichte")
plt.xlim(0,250)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %%
catcols = ['Intake Type',
       'Intake Condition', 
       'Status_in', 'Sex_in', 'Outcome Type', 'Outcome Subtype', 'Status_out',
       'Sex_out']

def catplot(col, data=merged_df, key = "Left", match=False, save_plot=False):
    '''Display 'col vs. key' barplots of... 
    ...on the left: A normalized crosstab for relative distributions.
    ...on the right: An absolute crosstab for checking the statistical significance for each category class.
    ARGS:
        col: Column name for the crosstabs' 'index'
        data (DataFrame): Data (default: df)
        key: Target column (default: 'IsBadBuy')
        match: target class to highlight (default: 1)
        save_plot (bool): Save plot as image file (default: False)
    RETURNS: None
    '''
    fig, ax = plt.subplots(figsize=(13,4), ncols=2)
    
    # Relative Verteilung
    crosstab_rel = pd.crosstab(index=data[col], columns=data[key], normalize='index')
    if match in crosstab_rel.columns:
        crosstab_rel[match].plot(kind='bar', ax=ax[0], color=['orange'], legend=False)
        ax[0].set_title(f'Relative Verteilung von {key} = {match} in {col}')
        ax[0].axhline(data[key].mean(), color="darkred", linestyle='--', label=f'Durchschnitt ({data[key].mean():.2f})')
        ax[0].legend()
    else:
        print(f"Warnung: Wert '{match}' nicht in {key} gefunden.")

    # 2. Absolute Verteilung (Einfache Häufigkeitszählung)
    # Wir zählen einfach, wie oft jede Kategorie in 'col' vorkommt
    # Keine normalize=True!
    counts = data[col].value_counts().sort_index() # sort_index für alphabetische/numerische Reihenfolge
    
    # Plot der absoluten Verteilung
    counts.plot(kind='bar', ax=ax[1], color='skyblue', legend=False)
    ax[1].set_title(f'Absolute Verteilung (Count) von {col}')
    ax[1].set_ylabel('Anzahl')
    
    # Optional: Gitterlinien für bessere Lesbarkeit
    ax[1].grid(axis='y', alpha=0.3)

    plt.tight_layout()
    
    if save_plot:
        fig.savefig(f"catplot_{col}.png")
        plt.close(fig) # Speicher und schließen, um Speicher zu sparen
    else:
        plt.show()

# Ausführung
for cat in catcols:
    catplot(cat)
# Out:
# Warnung: Wert 'False' nicht in Left gefunden.
# Warnung: Wert 'False' nicht in Left gefunden.
# Warnung: Wert 'False' nicht in Left gefunden.
# Warnung: Wert 'False' nicht in Left gefunden.

# %% [markdown]
# Auf Grund der guten Vermittlungsquote, denke ich an ein Modell, das mit der Dauer im Tierheim arbietet, oder auch an unüberwachtes lernen. Ich halte die Daten für soweit aufbereitet, dass man damit nun Arbeiten kann. Deswegen wird ein neues Notebook erstellt, in dem mit merged_df gearbeitet wird. Dazu speichere ich merged_df als pickle.

# %%
merged_df.to_pickle("shelter_data.pkl")
